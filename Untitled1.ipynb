# %%
import pandas as pd
from matplotlib import pyplot as plt
import random

df = pd.read_csv('data/sr.csv', encoding='utf-8', header=None)
df.columns = ['Time', 'Nick', 'Class', 'Rating']
df['Time'] = pd.to_datetime(df['Time']).dt.date
# df.set_index('Time')
df['Nick_Class'] = df['Nick'] +" " + df['Class']

date_range = pd.DataFrame(pd.date_range(min(df['Time']),max(df['Time']), freq='d'))
date_range.columns = ['Time']
date_range['Time'] = date_range['Time'].dt.date

print(df)
# Out:
#           Time        Nick    Class  Rating         Nick_Class
# 0   2021-03-02        slug      DPS    1637           slug DPS
# 1   2021-03-02        slug  Support    1999       slug Support
# 2   2021-03-02   LarsErikO  Support    1842  LarsErikO Support
# 3   2021-03-02      myoung  Support    2055     myoung Support
# 4   2021-03-02   Stiananan     Tank    1869     Stiananan Tank
# ..         ...         ...      ...     ...                ...
# 63  2021-03-22   LarsErikO  Support    1837  LarsErikO Support
# 64  2021-03-22  kidneypool     Tank    2187    kidneypool Tank
# 65  2021-03-23        slug      DPS    1817           slug DPS
# 66  2021-03-23   LarsErikO  Support    1905  LarsErikO Support
# 67  2021-03-23  kidneypool     Tank    2187    kidneypool Tank
#
# [68 rows x 5 columns]

# %%
df_pivot = df.pivot(index='Time', columns='Nick_Class', values='Rating')
print(df_pivot)
# Out:
# Nick_Class  LarsErikO Support  Stiananan Tank  kidneypool Tank  lundefugl DPS  \
# Time
# 2021-03-02             1842.0          1869.0           2143.0         2152.0
# 2021-03-03             1828.0          1788.0           2132.0         2069.0
# 2021-03-04             1828.0          1788.0           2129.0         2069.0
# 2021-03-05             1828.0          1788.0           2129.0         2069.0
# 2021-03-06             1828.0          1788.0           2129.0         2069.0
# 2021-03-07             1828.0          1788.0           2129.0         2069.0
# 2021-03-08             1828.0          1788.0           2129.0         2069.0
# 2021-03-09             1828.0             NaN           2129.0            NaN
# 2021-03-18             1733.0             NaN              NaN            NaN
# 2021-03-19             1861.0             NaN           2076.0            NaN
# 2021-03-20             1861.0             NaN           2142.0            NaN
# 2021-03-21             1861.0             NaN           2142.0            NaN
# 2021-03-22             1837.0             NaN           2187.0            NaN
# 2021-03-23             1905.0             NaN           2187.0            NaN
#
# Nick_Class  myoung Support  slug DPS  slug Support
# Time
# 2021-03-02          2055.0    1637.0        1999.0
# 2021-03-03          1983.0    1577.0        1999.0
# 2021-03-04          1983.0    1577.0        1999.0
# 2021-03-05          1983.0    1577.0        1999.0
# 2021-03-06          1983.0    1577.0        1999.0
# 2021-03-07          1983.0    1577.0        1999.0
# 2021-03-08          1983.0    1577.0        1999.0
# 2021-03-09          1983.0       NaN           NaN
# 2021-03-18             NaN       NaN           NaN
# 2021-03-19             NaN    1817.0           NaN
# 2021-03-20             NaN    1817.0           NaN
# 2021-03-21             NaN    1817.0           NaN
# 2021-03-22             NaN    1817.0           NaN
# 2021-03-23             NaN    1817.0           NaN

# %%
df_pivot.plot(figsize=(14,9), xticks=df['Time'].unique()).grid(axis='y')
plt.title(f'Skill Rating')
plt.legend(loc='lower left')
plt.show()

# %%
df_graph = date_range.merge(df_pivot, on='Time', how='left')
df_graph.fillna(method='ffill')
ax = df_graph.set_index('Time').fillna(method='ffill').plot(figsize=(14, 9), rot=90,xticks=df_graph['Time'])
ax.legend(loc='center left', bbox_to_anchor=(1.0, 0.5)) 
plt.show()
